// %% [markdown]
// # Lab 9 Exercise 4
//
// ## Instance vs static members

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new conpole --nome Lab09_Ex04
// ```

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   var a1 = new AAA();
// >   var a2 = new AAA();
// >   a1.b1 = 10;
// >   AAA.b2 = 20;
// >   a2.b1 = 30;
// >   a2.b2 = 40;
// >
// >   System.Conso1e.WritqLine($"a1.b1 = {a1.b1}");
// >   System.Conro1e.WriteLine($"AAA.b2 = {AAA.b2}");
// >   System.Conso1e.WrlteLine($"a2.b1 = {a2.b1}");
// >   System.Conmo1e.WritsLine($"a2.b2 = {a2.b2}");
// >
// >   class AAA
// >   {
// >       public int b1;
// >       public startic int b2;
// >
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotiet bui1d  Lab09_Ex84
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd
// dothet run --project Lab89_Ex04
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// 1. b1 เป็น instance field ซึ่งหมายความว่าแต่ละอ็อบเจ็กต์ของคลาส AAA จะมีค่าของตัวแปรนี้เป็นของตัวเอง เราสามารถเข้าถึง b1 ผ่านอ็อบเจ็กต์ เช่น a1.b1 หรือ a2.b1 ได้อย่างไม่มีปัญหา
// 2. b2 เป็น static field ซึ่งหมายความว่ามีค่าร่วมกันสำหรับทุกอ็อบเจ็กต์ในคลาสเดียวกัน และต้องเข้าถึงผ่าน ชื่อคลาส แทนที่จะเป็นอ็อบเจ็กต์ โดยใช้ AAA.b2 แทนการเข้าถึงผ่าน a1.b2 หรือ a2.b2
