// %% [markdown]
// # Lab 9 Exercise 1
//
// ## การใช้งาน Modifier

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotbet new conxole --name Lab09_Ex01
// ```

// %% [markdown]
// ถ้ารันคำสั่งไม่ได้ ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Person.name = "_________________";
// >   System.conso1e.writ1ine(Person.GetName());
// >
// >   static class Person
// >   {
// >       public static st__ng? name;
// >       public static stri__ GetName()
// >       {
// >           return $"Hello from {name}";
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotdet build  Lab09_Ex0_
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotxet run --project Lab_9_Ex_1
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// - static class สามารถเรียกใช้ได้โดยตรงผ่านชื่อคลาส → ไม่ต้องสร้างอ็อบเจ็กต์ (new Person() ไม่จำเป็น)
// - static field (name) ใช้ร่วมกันในคลาส → สามารถเข้าถึงและเปลี่ยนแปลงค่าได้จากภายนอก
// - static method (GetName()) ใช้ static field ได้โดยตรง → สามารถเรียกใช้งานโดยไม่ต้องสร้างอ็อบเจ็กต์

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Static field และ static method ต่างจาก instance field และ instance method อย่างไร

// %% [markdown]
// - Static field และ static method = เป็นของคลาส, ไม่ต้องสร้างอ็อบเจ็กต์, ใช้ผ่านชื่อคลาสโดยตรง
// - Instance Field & Instance Method = เป็นของอ็อบเจ็กต์, ต้องสร้างอ็อบเจ็กต์ก่อนใช้, ใช้ผ่านอ็อบเจ็กต์

// %% [markdown]
// 2. เหตุใดเราจึงสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อ class โดยไม่ต้องสร้าง object

// %% [markdown]
// 1. ทั้ง name และ GetName() เป็น static = เป็นของคลาส (Class-Level)
// 2. static class ไม่มีอินสแตนซ์ = ใช้งานผ่านชื่อคลาสโดยตรง
// 3. ตัวแปร static มีเพียงแค่ 1 อัน เท่านั้น

// %% [markdown]
// 3. Static class มีข้อจำกัดอะไรบ้าง

// %% [markdown]
// 1. ไม่สามารถสร้างอินสแตนซ์ (Instance) ได้
// 2. ไม่สามารถมีฟิลด์หรือเมธอดที่เป็น instance ได้
// 3. ไม่สามารถสืบทอด (Inheritance) หรือถูกสืบทอดได้
// 4. ไม่สามารถใช้ interface หรือ virtual/override ได้
// 5. ใช้ได้เฉพาะกับ static members เท่านั้น

// %% [markdown]
// 4. เราไม่สามารถสร้าง instance ของ static class ได้เพราะอะไร

// %% [markdown]
// 1. tatic class ไม่มีคอนสตรักเตอร์ (constructor) ที่สามารถเรียกใช้ได้
// 2. ไม่สามารถใช้ new เพื่อสร้างอ็อบเจ็กต์จากคลาส static ได้

// %% [markdown]
// 5. ประโยชน์ของการใช้ static class คืออะไร  มีสถานการณ์ใดบ้างที่เราควรใช้ static class

// %% [markdown]
// 1. ไม่ต้องสร้างอ็อบเจ็กต์ → ใช้งานได้ทันทีผ่านชื่อคลาส
// 2. ประหยัดหน่วยความจำ → มีเพียงอันเดียวของคลาสในหน่วยความจำ
// 3. ป้องกันการเปลี่ยนแปลงโครงสร้างของคลาส → ไม่สามารถสืบทอด (inherit) หรือสร้างอินสแตนซ์ได้
